# %% [markdown]
# <a href="https://colab.research.google.com/github/GaurangRawat/Machine-Learning-Projects/blob/main/ML%20Projects%20/Project%202/Survival_On_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # ***Reading Data***

# %%
df = pd.read_csv("data.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %% [markdown]
# # ***Basic Operation***

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop(['Cabin','Name','PassengerId','Ticket'], axis=1 , inplace=True )

# %%
df.head(2)
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (712, 8)

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Gender    712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169   29.642093    0.514045    0.432584   34.567251
# std      0.491139    0.836854   14.492933    0.930692    0.854181   52.938648
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    2.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    3.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# # ***Now Look At Each Column Specifically***

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Gender', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %% [markdown]
# 1. **Survived**

# %%
df["Survived"].value_counts()
# Out:
# Survived
# 0    424
# 1    288
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="Survived",data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# 2. **PClass**

# %%
df["Pclass"].value_counts()
# Out:
# Pclass
# 3    355
# 1    184
# 2    173
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="Pclass",data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# 3. Gender

# %%
df["Gender"].value_counts()
# Out:
# Gender
# male      453
# female    259
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="Gender", data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# 4. Embarked

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    554
# C    130
# Q     28
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="Embarked",data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# 5. **SibSP**

# %%
df["SibSp"].value_counts()
# Out:
# SibSp
# 0    469
# 1    183
# 2     25
# 4     18
# 3     12
# 5      5
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="SibSp",data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# 6. **ParCH**

# %%
df["Parch"].value_counts()
# Out:
# Parch
# 0    519
# 1    110
# 2     68
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(2,2))
sns.countplot(x="Parch",data=df)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# 7. **Age**

# %%
df["Age"].describe()
# Out:
# count    712.000000
# mean      29.642093
# std       14.492933
# min        0.420000
# 25%       20.000000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(3,3))
plt.hist(df["Age"])
plt.show()

# %% [markdown]
# 8. **Fare**

# %%
df["Fare"].describe()
# Out:
# count    712.000000
# mean      34.567251
# std       52.938648
# min        0.000000
# 25%        8.050000
# 50%       15.645850
# 75%       33.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
plt.hist(df["Fare"])
plt.show()

# %% [markdown]
# # Getting More ***Insights***

# %% [markdown]
# 1. Survived with ***Gender***

# %%
df.head(2)
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C

# %%
grouped_data=df.groupby(['Gender','Survived']).size().unstack()
grouped_data
# Out:
# Survived    0    1
# Gender
# female     64  195
# male      360   93

# %%
plt.figure(figsize=(3,3))

grouped_data.plot(kind='bar', stacked=False)

plt.title('Survived VS Gender')
plt.xlabel('Gender')
plt.ylabel('Number of People')
plt.legend(title='Survived', labels=['No','Yes'])
plt.show()

# %% [markdown]
# 2. PClass and **Survived**

# %%
df.head(2)
# Out:
#    Survived  Pclass  Gender   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C

# %%
grouped_data=df.groupby(['Pclass','Survived']).size().unstack()
grouped_data
# Out:
# Survived    0    1
# Pclass
# 1          64  120
# 2          90   83
# 3         270   85

# %%
plt.figure(figsize=(3,3))

grouped_data.plot(kind='bar', stacked=True)

plt.title("PClass VS Survived")
plt.xlabel("Passenger Class")
plt.ylabel("Number of People")
plt.legend("Survived", labels=['NO','Yes'])
plt.show()
# Out:
# <ipython-input-51-0e86b6b77265>:8: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   plt.legend("Survived", labels=['NO','Yes'])

# %% [markdown]
# 3. Survival By **Age**

# %%
plt.figure(figsize=(4,4))
sns.kdeplot(df[df["Survived"]==1]["Age"], color='green', label='Survived')
sns.kdeplot(df[df['Survived']==0]['Age'], color='red', label='Did Not Survive')
plt.title('Age distribution with Survival Status')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# 4. Survival by Fare

# %%
plt.figure(figsize=(4,4))
sns.kdeplot(df[df['Survived']==1]['Fare'], color='green', label='Survived')
sns.kdeplot(df[df['Survived']==0]['Fare'], color= 'red', label='Did not Survive')
plt.title('Fare Distribution by Survival Status')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
corr_matrix = df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-b69b4b6a6184> in <cell line: 1>()
# ----> 1 corr_matrix = df.corr()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994         if result.dtype is not dtype:
#    1995             result = np.asarray(result, dtype=dtype)
#
# ...

# %%
numeric_df = df.select_dtypes(include=['float64','int64'])

#compute correlation matrix
corr_matrix = numeric_df.corr()

#Plotting the correlation matrix
plt.figure(figsize=(4,4))
sns.heatmap(corr_matrix, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Titanic Dataset')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.pairplot(df)

# %% [markdown]
# 6. Age Vs Gender

# %%
male_data= df[df['Gender']=='male']
female_data= df[df['Gender']=='female']

# Plot histograms for each gender seperately
sns.histplot(data=male_data, x='Age', bins=20, color='blue', alpha=0.5, label='Male')
sns.histplot(data=female_data, x='Age', bins=20, color='pink', alpha=0.5, label='Female')

plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend()
plt.show()
